# %% [markdown]
# # Extraindo textos de pdfs
# Hoje em dia é muito mais fácil encontrar dados na internet. Mas nem toda fonte encontrada na internet está no mesmo formato. O formato de documento portátil, **PDF**, é apenas um, entre tantos. <br>
# Em muitos casos, o famoso copia e cola é suficiente para extrair o texto de um pdf. Pra que Python, afinal?<br>
#
# Quando o material for extenso, ou os dados se encontrarem dispersos em vários pdfs, **Python** pode ajudar na extração e na exploração desses dados.
#
# **ATENÇÃO**: O objetivo é compartilhar a utilidade e praticidade de usar  **Python** para pesquisas na área de letras. Então, o (pouco)código será executado uma parte de cada vez. Obviamente há maneiras mas práticas e rápidas de realizar as mesmas tarefas.

# %% [markdown]
# ### PyPDF2
# Precisaremos recorrer a uma biblioteca para interagir com pdfs em Python. Desta vez escolhemos **PyPDF2**.
# - Para instalar 0 PyPDF2 pelo jupyter notebook: pip install PyPDF2

# %%
# pip install PyPDF2

# %% [markdown]
# # 1. Importando a biblioteca PyPDF2

# %%
import PyPDF2

# %% [markdown]
# # 2. Abrir, ler e extrair o texto do pdf
# A extração do texto do pdf ocorre em 3 etapas
#
# >Para poder-mos interagir com o pdf com PyPDF2, é imprecindível usar o modo 'rb'(leitura/escrita).
#
# **1. Cria uma variável *pdf* e salva a leitura do *arquivo* nessa variável**
# - Usamos a função *PdfFileReader()* do PyPDF2 para **ler** o pdf.
#
# **2. Seleciona a página do arquivo de que desejamos extrair o texto**
# - Utlizamos *getPage()* para reter a página do arquivo desejada e criamos um objeto chamado *pagina*. Mesmo nosso arquivo contendo apenas 1 página, essa etapa é necessária. A contagem começa do 0. Por isso para indicar a página 1 do arquivo, utilizamos o 0.
#
# **3. Salva o texto extraido da página selecionada em uma variável**
# - Aplicamos a função *extractText()* à página selecionada e salvamos em uma variável, novamente, para a nossa conveniencia.

# %%
with open('cda_aeroporto.pdf', 'rb') as arquivo:
    # 1º ETAPA
    pdf = PyPDF2.PdfFileReader(arquivo)
    
    # 2º ETAPA
    pagina = pdf.getPage(0)
    
    # 3º ETAPA
    texto_extraido = pagina.extractText()

# %% [markdown]
# ### Vamos visualizar o resultado
# A primeira coisa que você vai notar é que não há uma formatação no texto. E que a combinação estranha *\n* se repete ao longo do texto. Não se aflija!<br> <br>

# %%
texto_extraido
# Out:
# 'Aeroporto\n \n \nViajou meu amigo Pedro. Fui levá\n-\nlo ao Galeão, onde esperamos três horas o seu \nquadrimotor. \nDurante esse tempo, não faltou assunto para nos entretermos, embora não \nfalássemos da vã e numerosa matéria atual. Sempre tivemos muito assunto, e não \ndeixamos de explorá\n-\nla a fundo. Embora Pedro seja extremamente parco de palavras e, a \nbem dizer, não se d\nigne pronunciar nenhuma. Quando muito, emite sílabas: o mais é \nconversa de gestos e expressões, pelos quais se faz entender admiravelmente. É o seu \nsistema. Passou dois meses e meio em nossa casa, e foi hóspede ameno. Sorria para os \nmoradores, com ou sem m\notivo plausível. Era sua arma, não direi secreta, porque \nostensiva. A vista da pessoa humana lhe dá prazer. Seu sorriso foi logo considerado \nsorriso especial, revelador de suas intenções para com o mundo ocidental e o oriental, e \nem particular o nosso trec\nho de rua. Fornecedores, vizinhos e desconhecidos, gratificados \ncom esse sorriso (encantador, apesar da falta de dentes), abonam a classificação. Devo \nadmitir que Pedro, como visitante, nos deu trabalho: tinha horários especiais, comidas \nespeciais, roupas \nespeciais, sabonetes especiais, criados especiais. Mas sua simples \npresença e seu sorriso compensariam providências e privilégios maiores. Recebia tudo \ncom naturalidade, sabendo\n-\nse merecedor das distinções, e ninguém se lembraria de achá\n-\nlo egoísta ou inop\nortuno. Suas horas de sono \n\n \ne lhe apraz dormir não só à noite como \nprincipalmente de dia \n\n \neram respeitadas como ritos sacros a ponto de não ousarmos \nerguer a voz para não acordá\n-\nlo. Acordaria sorrindo, como de costume, e não se zangaria \ncom a gente, poré\nm é que não nos perdoaríamos o corte de seus sonhos. Assim, por conta \nde Pedro, deixamos de ouvir muito concerto para violino e orquestra, de Bach, mas \ntambém nossos olhos e ouvidos se forraram à tortura da TV. Andando na ponta dos pés, \nou descalços, levam\nos tropeções no escuro, mas sendo por amor de Pedro não tinha \nimportância. Objeto que visse em nossa mão, requisitava\n-\no. Gosta de óculos alheios (e \nnão os usa), relógios de pulso, copos, xícaras e vidros em geral, artigos de escritório, \nbotões simples ou d\ne punho. Não é colecionador; gosta das coisas para pegá\n-\nlas, mirá\n-\nlas \ne (é seu costume ou sua mania, que se há de fazer) pô\n-\nlas na boca. Quem não o conhecer \ndirá que é péssimo costume, porém duvido que mantenha este juízo diante de Pedro, de \nseu sorriso se\nm malícia e de suas pupilas azuis \n\n \nporque me esquecia de dizer que tem \nolhos azuis, cor que afasta qualquer suspeita ou acusação apressada sobre a razão íntima \nde seus atos. Poderia acusá\n-\nlo de incontinência, porque não sabia distinguir entre os \ncômodos, \ne o que lhe ocorria fazer, fazia em qualquer parte? Zangar\n-\nme com ele porque \ndestruiu a lâmpada do escritório? Não. Jamais me voltei para Pedro que ele não me \nsorrisse; tivesse eu um impulso de irritação, e me sentiria desarmado com a sua azul \nmaneira de o\nlhar\n-\nme. Eu sabia que essas coisas eram indiferentes à nossa amizade \n\n \ne, \naté, que a nossa amizade lhes conferia caráter necessário, de prova; ou gratuito, de poesia \ne jogo. Viajou meu amigo Pedro. Fico refletindo na falta que faz um amigo de um ano de \nida\nde a seu companheiro já vivido e puído. De repente o aeroporto ficou vazio.\n \n'

# %% [markdown]
# #### Quanto menos formatação, menos trabalho!
# O *\n* é só um resquício de formatação. Onde no texto há uma quebra de linha, aparece o *\n* no lugar.<br><br>
# Vamos visualizar melhor usando a função **print()** para exibir o conteúdo.

# %%
print(texto_extraido)
# Viu?!
# Out:
# Aeroporto
#
#
# Viajou meu amigo Pedro. Fui levá
# -
# lo ao Galeão, onde esperamos três horas o seu
# quadrimotor.
# Durante esse tempo, não faltou assunto para nos entretermos, embora não
# falássemos da vã e numerosa matéria atual. Sempre tivemos muito assunto, e não
# deixamos de explorá
# -
# la a fundo. Embora Pedro seja extremamente parco de palavras e, a
# bem dizer, não se d
# igne pronunciar nenhuma. Quando muito, emite sílabas: o mais é
# conversa de gestos e expressões, pelos quais se faz entender admiravelmente. É o seu
# sistema. Passou dois meses e meio em nossa casa, e foi hóspede ameno. Sorria para os
# moradores, com ou sem m
# otivo plausível. Era sua arma, não direi secreta, porque
# ostensiva. A vista da pessoa humana lhe dá prazer. Seu sorriso foi logo considerado
# sorriso especial, revelador de suas intenções para com o mundo ocidental e o oriental, e
# em particular o nosso trec
# ho de rua. Fornecedores, vizinhos e desconhecidos, gratificados
# com esse sorriso (encantador, apesar da falta de dentes), abonam a classificação. Devo
# admitir que Pedro, como visitante, nos deu trabalho: tinha horários especiais, comidas
# especiais, roupas
# especiais, sabonetes especiais, criados especiais. Mas sua simples
# presença e seu sorriso compensariam providências e privilégios maiores. Recebia tudo
# com naturalidade, sabendo
# -
# se merecedor das distinções, e ninguém se lembraria de achá
# -
# lo egoísta ou inop
# ortuno. Suas horas de sono
#
#
# e lhe apraz dormir não só à noite como
# principalmente de dia
#
#
# eram respeitadas como ritos sacros a ponto de não ousarmos
# erguer a voz para não acordá
# -
# lo. Acordaria sorrindo, como de costume, e não se zangaria
# com a gente, poré
# m é que não nos perdoaríamos o corte de seus sonhos. Assim, por conta
# de Pedro, deixamos de ouvir muito concerto para violino e orquestra, de Bach, mas
# também nossos olhos e ouvidos se forraram à tortura da TV. Andando na ponta dos pés,
# ou descalços, levam
# os tropeções no escuro, mas sendo por amor de Pedro não tinha
# importância. Objeto que visse em nossa mão, requisitava
# -
# o. Gosta de óculos alheios (e
# não os usa), relógios de pulso, copos, xícaras e vidros em geral, artigos de escritório,
# botões simples ou d
# e punho. Não é colecionador; gosta das coisas para pegá
# -
# las, mirá
# -
# las
# e (é seu costume ou sua mania, que se há de fazer) pô
# -
# las na boca. Quem não o conhecer
# dirá que é péssimo costume, porém duvido que mantenha este juízo diante de Pedro, de
# seu sorriso se
# m malícia e de suas pupilas azuis
#
#
# porque me esquecia de dizer que tem
# olhos azuis, cor que afasta qualquer suspeita ou acusação apressada sobre a razão íntima
# de seus atos. Poderia acusá
# -
# lo de incontinência, porque não sabia distinguir entre os
# cômodos,
# e o que lhe ocorria fazer, fazia em qualquer parte? Zangar
# -
# me com ele porque
# destruiu a lâmpada do escritório? Não. Jamais me voltei para Pedro que ele não me
# sorrisse; tivesse eu um impulso de irritação, e me sentiria desarmado com a sua azul
# maneira de o
# lhar
# -
# me. Eu sabia que essas coisas eram indiferentes à nossa amizade
#
#
# e,
# até, que a nossa amizade lhes conferia caráter necessário, de prova; ou gratuito, de poesia
# e jogo. Viajou meu amigo Pedro. Fico refletindo na falta que faz um amigo de um ano de
# ida
# de a seu companheiro já vivido e puído. De repente o aeroporto ficou vazio.

# %% [markdown]
# Ainda é uma formatação estranha. Note que cada vez que há uma palavra com pronome oblíquo atono, que utliza o símbolo "-", há uma quebra de linha. <br>
# Faremos as intervenções necessárias, mas antes vamos salvar o texto em formato mais simples, o formato *txt*.

# %% [markdown]
# #### Vamos exibir os 100 primeiros caracteres do texto para analisar

# %%
texto_extraido[:100]
# Out:
# 'Aeroporto\n \n \nViajou meu amigo Pedro. Fui levá\n-\nlo ao Galeão, onde esperamos três horas o seu \nquad'

# %% [markdown]
# ### Função replace(  )
# Vamos usar a função *replace()* para retirar essa anomalia nos pronomes obliquos atonos.
# <br><br>
# A função *replace()* recebe *dois parâmetros*:
# - O *primeiro* se refere a um aspécto existente no texto. No nosso caso, o *\n-\n* entre o verbo e o pronome (ex: levá\n-\nlo ).
# - O *segundo* parâmetro se refere ao que nós desejamos inserir no lugar desta anomalia.

# %%
texto_extraido[:100].replace('\n-\n', '-')
# Out:
# 'Aeroporto\n \n \nViajou meu amigo Pedro. Fui levá-lo ao Galeão, onde esperamos três horas o seu \nquad'

# %% [markdown]
# #### Resultado satisfatório, mas...
# Conseguimos deixar a palavra como ela apareceria em textos para humanos ler. Mas, como queremos que um pragama, Python, leia e nos retorne outras informações, não vamos mais nos deter na quebra de linha (para o programa isso não afetará a leitura). Ao invés disso, vamos **noramalizar** o texto (remover a pontuação, e deixar tudo em letras minusculas). Isto, usando a mesma função .**replace()** e a função **lower()** no final.<Br><br>
# **Atenção**: A barra ivertida ao final de cada repalce( ) é apenas para colocar o código em uma segunda linha. Caso contrario, teriamos uma linha muito longa de replaces .replace('.','').replace(',','').replace('?','')...

# %%
texto_extraido[:290].replace('\n-\n', '-')\
            .replace('.','')\
            .replace(',','')\
            .replace('?','')\
            .replace('(','')\
            .replace(')','')\
            .lower()
# Out:
# 'aeroporto\n \n \nviajou meu amigo pedro fui levá-lo ao galeão onde esperamos três horas o seu \nquadrimotor \ndurante esse tempo não faltou assunto para nos entretermos embora não \nfalássemos da vã e numerosa matéria atual sempre tivemos muito assunto e não \ndeixamos de explorá-la a '

# %% [markdown]
# #### Vamos aplicar as modificações acima no texto inteiro e salvar em uma nova variável
# As modificações acima não afetam o texto original. Então vamos salvar o texto modificado em uma variavel.

# %%
sem_pontuacao = texto_extraido.replace('\n-\n', '-')\
            .replace('.','')\
            .replace(',','')\
            .replace('?','')\
            .replace('(','')\
            .replace(')','')\
            .lower()

# %%
print(sem_pontuacao)
# resultado sem pontuação
# Out:
# aeroporto
#
#
# viajou meu amigo pedro fui levá-lo ao galeão onde esperamos três horas o seu
# quadrimotor
# durante esse tempo não faltou assunto para nos entretermos embora não
# falássemos da vã e numerosa matéria atual sempre tivemos muito assunto e não
# deixamos de explorá-la a fundo embora pedro seja extremamente parco de palavras e a
# bem dizer não se d
# igne pronunciar nenhuma quando muito emite sílabas: o mais é
# conversa de gestos e expressões pelos quais se faz entender admiravelmente é o seu
# sistema passou dois meses e meio em nossa casa e foi hóspede ameno sorria para os
# moradores com ou sem m
# otivo plausível era sua arma não direi secreta porque
# ostensiva a vista da pessoa humana lhe dá prazer seu sorriso foi logo considerado
# sorriso especial revelador de suas intenções para com o mundo ocidental e o oriental e
# em particular o nosso trec
# ho de rua fornecedores vizinhos e desconhecidos gratificados
# com esse sorriso encantador apesar da falta de dentes abonam a classificação devo
# admitir que pedro como visitante nos deu trabalho: tinha horários especiais comidas
# especiais roupas
# especiais sabonetes especiais criados especiais mas sua simples
# presença e seu sorriso compensariam providências e privilégios maiores recebia tudo
# com naturalidade sabendo-se merecedor das distinções e ninguém se lembraria de achá-lo egoísta ou inop
# ortuno suas horas de sono
#
#
# e lhe apraz dormir não só à noite como
# principalmente de dia
#
#
# eram respeitadas como ritos sacros a ponto de não ousarmos
# erguer a voz para não acordá-lo acordaria sorrindo como de costume e não se zangaria
# com a gente poré
# m é que não nos perdoaríamos o corte de seus sonhos assim por conta
# de pedro deixamos de ouvir muito concerto para violino e orquestra de bach mas
# também nossos olhos e ouvidos se forraram à tortura da tv andando na ponta dos pés
# ou descalços levam
# os tropeções no escuro mas sendo por amor de pedro não tinha
# importância objeto que visse em nossa mão requisitava-o gosta de óculos alheios e
# não os usa relógios de pulso copos xícaras e vidros em geral artigos de escritório
# botões simples ou d
# e punho não é colecionador; gosta das coisas para pegá-las mirá-las
# e é seu costume ou sua mania que se há de fazer pô-las na boca quem não o conhecer
# dirá que é péssimo costume porém duvido que mantenha este juízo diante de pedro de
# seu sorriso se
# m malícia e de suas pupilas azuis
#
#
# porque me esquecia de dizer que tem
# olhos azuis cor que afasta qualquer suspeita ou acusação apressada sobre a razão íntima
# de seus atos poderia acusá-lo de incontinência porque não sabia distinguir entre os
# cômodos
# e o que lhe ocorria fazer fazia em qualquer parte zangar-me com ele porque
# destruiu a lâmpada do escritório não jamais me voltei para pedro que ele não me
# sorrisse; tivesse eu um impulso de irritação e me sentiria desarmado com a sua azul
# maneira de o
# lhar-me eu sabia que essas coisas eram indiferentes à nossa amizade
#
#
# e
# até que a nossa amizade lhes conferia caráter necessário de prova; ou gratuito de poesia
# e jogo viajou meu amigo pedro fico refletindo na falta que faz um amigo de um ano de
# ida
# de a seu companheiro já vivido e puído de repente o aeroporto ficou vazio

# %% [markdown]
# ## Digamos que agora nós queiramos transformar o texto em segmentos de palavras
# Faremos isso com uma função chamda **split()**

# %%
sem_pontuacao.split()
# Out:
# ['aeroporto',
#  'viajou',
#  'meu',
#  'amigo',
#  'pedro',
#  'fui',
#  'levá-lo',
#  'ao',
#  'galeão',
#  'onde',
#  'esperamos',
#  'três',
#  'horas',
#  'o',
#  'seu',
#  'quadrimotor',
#  'durante',
#  'esse',
#  'tempo',
#  'não',
#  'faltou',
#  'assunto',
#  'para',
#  'nos',
#  'entretermos',
#  'embora',
#  'não',
#  'falássemos',
#  'da',
#  'vã',
#  'e',
#  'numerosa',
#  'matéria',
#  'atual',
#  'sempre',
#  'tivemos',
#  'muito',
#  'assunto',
#  'e',
#  'não',
#  'deixamos',
#  'de',
#  'explorá-la',
#  'a',
#  'fundo',
#  'embora',
#  'pedro',
#  'seja',
#  'extremamente',
#  'parco',
#  'de',
#  'palavras',
#  'e',
#  'a',
#  'bem',
#  'dizer',
#  'não',
#  'se',
#  'd',
#  'igne',
#  'pronunciar',
#  'nenhuma',
#  'quando',
#  'muito',
#  'emite',
#  'sílabas:',
#  'o',
#  'mais',
#  'é',
#  'conversa',
#  'de',
#  'gestos',
#  'e',
#  'expressões',
#  'pelos',
#  'quais',
#  'se',
#  'faz',
#  'entender',
#  'admiravelmente',
#  'é',
#  'o',
#  'seu',
#  'sistema',
#  'passou',
#  'dois',
#  'meses',
#  'e',
#  'meio',
#  'em',
#  'nossa',
#  'casa',
#  'e',
#  'foi',
#  'hóspede',
#  'ameno',
#  'sorria',
#  'para',
#  'os',
#  'moradores',
#  'com',
#  'ou',
#  'sem',
#  'm',
#  'otivo',
#  'plausível',
#  'era',
#  'sua',
#  'arma',
#  'não',
#  'direi',
#  'secreta',
#  'porque',
#  'ostensiva',
#  'a',
#  'vista',
#  'da',
#  'pessoa',
#  'humana',
#  'lhe',
#  'dá',
#  'prazer',
#  'seu',
#  'sorriso',
#  'foi',
#  'logo',
#  'considerado',
#  'sorriso',
#  'especial',
#  'revelador',
#  'de',
#  'suas',
#  'intenções',
#  'para',
#  'com',
#  'o',
#  'mundo',
#  'ocidental',
#  'e',
#  'o',
#  'oriental',
#  'e',
#  'em',
#  'particular',
#  'o',
#  'nosso',
#  'trec',
#  'ho',
#  'de',
#  'rua',
#  'fornecedores',
#  'vizinhos',
#  'e',
#  'desconhecidos',
#  'gratificados',
#  'com',
#  'esse',
#  'sorriso',
#  'encantador',
#  'apesar',
#  'da',
#  'falta',
#  'de',
#  'dentes',
#  'abonam',
#  'a',
#  'classificação',
#  'devo',
#  'admitir',
#  'que',
#  'pedro',
#  'como',
#  'visitante',
#  'nos',
#  'deu',
#  'trabalho:',
#  'tinha',
#  'horários',
#  'especiais',
#  'comidas',
#  'especiais',
#  'roupas',
#  'especiais',
#  'sabonetes',
#  'especiais',
#  'criados',
#  'especiais',
#  'mas',
#  'sua',
#  'simples',
#  'presença',
#  'e',
#  'seu',
#  'sorriso',
#  'compensariam',
#  'providências',
#  'e',
#  'privilégios',
#  'maiores',
#  'recebia',
#  'tudo',
#  'com',
#  'naturalidade',
#  'sabendo-se',
#  'merecedor',
#  'das',
#  'distinções',
#  'e',
#  'ninguém',
#  'se',
#  'lembraria',
#  'de',
#  'achá-lo',
#  'egoísta',
#  'ou',
#  'inop',
#  'ortuno',
#  'suas',
#  'horas',
#  'de',
#  'sono',
#  'e',
#  'lhe',
#  'apraz',
#  'dormir',
#  'não',
#  'só',
#  'à',
#  'noite',
#  'como',
#  'principalmente',
#  'de',
#  'dia',
#  'eram',
#  'respeitadas',
#  'como',
#  'ritos',
#  'sacros',
#  'a',
#  'ponto',
#  'de',
#  'não',
#  'ousarmos',
#  'erguer',
#  'a',
#  'voz',
#  'para',
#  'não',
#  'acordá-lo',
#  'acordaria',
#  'sorrindo',
#  'como',
#  'de',
#  'costume',
#  'e',
#  'não',
#  'se',
#  'zangaria',
#  'com',
#  'a',
#  'gente',
#  'poré',
#  'm',
#  'é',
#  'que',
#  'não',
#  'nos',
#  'perdoaríamos',
#  'o',
#  'corte',
#  'de',
#  'seus',
#  'sonhos',
#  'assim',
#  'por',
#  'conta',
#  'de',
#  'pedro',
#  'deixamos',
#  'de',
#  'ouvir',
#  'muito',
#  'concerto',
#  'para',
#  'violino',
#  'e',
#  'orquestra',
#  'de',
#  'bach',
#  'mas',
#  'também',
#  'nossos',
#  'olhos',
#  'e',
#  'ouvidos',
#  'se',
#  'forraram',
#  'à',
#  'tortura',
#  'da',
#  'tv',
#  'andando',
#  'na',
#  'ponta',
#  'dos',
#  'pés',
#  'ou',
#  'descalços',
#  'levam',
#  'os',
#  'tropeções',
#  'no',
#  'escuro',
#  'mas',
#  'sendo',
#  'por',
#  'amor',
#  'de',
#  'pedro',
#  'não',
#  'tinha',
#  'importância',
#  'objeto',
#  'que',
#  'visse',
#  'em',
#  'nossa',
#  'mão',
#  'requisitava-o',
#  'gosta',
#  'de',
#  'óculos',
#  'alheios',
#  'e',
#  'não',
#  'os',
#  'usa',
#  'relógios',
#  'de',
#  'pulso',
#  'copos',
#  'xícaras',
#  'e',
#  'vidros',
#  'em',
#  'geral',
#  'artigos',
#  'de',
#  'escritório',
#  'botões',
#  'simples',
#  'ou',
#  'd',
#  'e',
#  'punho',
#  'não',
#  'é',
#  'colecionador;',
#  'gosta',
#  'das',
#  'coisas',
#  'para',
#  'pegá-las',
#  'mirá-las',
#  'e',
#  'é',
#  'seu',
#  'costume',
#  'ou',
#  'sua',
#  'mania',
#  'que',
#  'se',
#  'há',
#  'de',
#  'fazer',
#  'pô-las',
#  'na',
#  'boca',
#  'quem',
#  'não',
#  'o',
#  'conhecer',
#  'dirá',
#  'que',
#  'é',
#  'péssimo',
#  'costume',
#  'porém',
#  'duvido',
#  'que',
#  'mantenha',
#  'este',
#  'juízo',
#  'diante',
#  'de',
#  'pedro',
#  'de',
#  'seu',
#  'sorriso',
#  'se',
#  'm',
#  'malícia',
#  'e',
#  'de',
#  'suas',
#  'pupilas',
#  'azuis',
#  'porque',
#  'me',
#  'esquecia',
#  'de',
#  'dizer',
#  'que',
#  'tem',
#  'olhos',
#  'azuis',
#  'cor',
#  'que',
#  'afasta',
#  'qualquer',
#  'suspeita',
#  'ou',
#  'acusação',
#  'apressada',
#  'sobre',
#  'a',
#  'razão',
#  'íntima',
#  'de',
#  'seus',
#  'atos',
#  'poderia',
#  'acusá-lo',
#  'de',
#  'incontinência',
#  'porque',
#  'não',
#  'sabia',
#  'distinguir',
#  'entre',
#  'os',
#  'cômodos',
#  'e',
#  'o',
#  'que',
#  'lhe',
#  'ocorria',
#  'fazer',
#  'fazia',
#  'em',
#  'qualquer',
#  'parte',
#  'zangar-me',
#  'com',
#  'ele',
#  'porque',
#  'destruiu',
#  'a',
#  'lâmpada',
#  'do',
#  'escritório',
#  'não',
#  'jamais',
#  'me',
#  'voltei',
#  'para',
#  'pedro',
#  'que',
#  'ele',
#  'não',
#  'me',
#  'sorrisse;',
#  'tivesse',
#  'eu',
#  'um',
#  'impulso',
#  'de',
#  'irritação',
#  'e',
#  'me',
#  'sentiria',
#  'desarmado',
#  'com',
#  'a',
#  'sua',
#  'azul',
#  'maneira',
#  'de',
#  'o',
#  'lhar-me',
#  'eu',
#  'sabia',
#  'que',
#  'essas',
#  'coisas',
#  'eram',
#  'indiferentes',
#  'à',
#  'nossa',
#  'amizade',
#  'e',
#  'até',
#  'que',
#  'a',
#  'nossa',
#  'amizade',
#  'lhes',
#  'conferia',
#  'caráter',
#  'necessário',
#  'de',
#  'prova;',
#  'ou',
#  'gratuito',
#  'de',
#  'poesia',
#  'e',
#  'jogo',
#  'viajou',
#  'meu',
#  'amigo',
#  'pedro',
#  'fico',
#  'refletindo',
#  'na',
#  'falta',
#  'que',
#  'faz',
#  'um',
#  'amigo',
#  'de',
#  'um',
#  'ano',
#  'de',
#  'ida',
#  'de',
#  'a',
#  'seu',
#  'companheiro',
#  'já',
#  'vivido',
#  'e',
#  'puído',
#  'de',
#  'repente',
#  'o',
#  'aeroporto',
#  'ficou',
#  'vazio']

# %% [markdown]
# ### Quantas palavras há no texto?

# %%
len(sem_pontuacao.split())
# Out:
# 550

# %% [markdown]
# ### Você piscou e já estamos explorando o arquivo ;)
# Para terminar, vamos criar uma lista com as palavras do texto. Faremos isso salvando a função split() aplicada ao texto em uma variável.

# %%
palavras = sem_pontuacao.split()

# %% [markdown]
# ### Que tal contar as palavras por ocorrência? Qual a palavra que mais se repete?
# Primeiro a gente cria um repositório vazio para receber as palavras contadas. A gente vai chamar esse repositório de... repositório mesmo!
# <br><br>
# Depois vamos escrever um laço de repetição (loop) para que a cada palavra nova, ela seja guardada no repositório. E se palavra for repetida, a quantidade seja guardada ao lado da palavra. O formato de dicionário do Python deixa tudo organizadinho para a gente.

# %%
repositório = dict()

for palavra in palavras:
    
    if palavra not in repositório:
        repositório[palavra] = 1
    else:
        repositório[palavra] = repositório[palavra] + 1

# %% [markdown]
# ### Exibindo o resultado

# %%
repositório
# Olha aí: a palavra e a quantidade de vezes que ela aparece
# Out:
# {'aeroporto': 2,
#  'viajou': 2,
#  'meu': 2,
#  'amigo': 3,
#  'pedro': 8,
#  'fui': 1,
#  'levá-lo': 1,
#  'ao': 1,
#  'galeão': 1,
#  'onde': 1,
#  'esperamos': 1,
#  'três': 1,
#  'horas': 2,
#  'o': 11,
#  'seu': 7,
#  'quadrimotor': 1,
#  'durante': 1,
#  'esse': 2,
#  'tempo': 1,
#  'não': 17,
#  'faltou': 1,
#  'assunto': 2,
#  'para': 7,
#  'nos': 3,
#  'entretermos': 1,
#  'embora': 2,
#  'falássemos': 1,
#  'da': 4,
#  'vã': 1,
#  'e': 26,
#  'numerosa': 1,
#  'matéria': 1,
#  'atual': 1,
#  'sempre': 1,
#  'tivemos': 1,
#  'muito': 3,
#  'deixamos': 2,
#  'de': 34,
#  'explorá-la': 1,
#  'a': 12,
#  'fundo': 1,
#  'seja': 1,
#  'extremamente': 1,
#  'parco': 1,
#  'palavras': 1,
#  'bem': 1,
#  'dizer': 2,
#  'se': 7,
#  'd': 2,
#  'igne': 1,
#  'pronunciar': 1,
#  'nenhuma': 1,
#  'quando': 1,
#  'emite': 1,
#  'sílabas:': 1,
#  'mais': 1,
#  'é': 6,
#  'conversa': 1,
#  'gestos': 1,
#  'expressões': 1,
#  'pelos': 1,
#  'quais': 1,
#  'faz': 2,
#  'entender': 1,
#  'admiravelmente': 1,
#  'sistema': 1,
#  'passou': 1,
#  'dois': 1,
#  'meses': 1,
#  'meio': 1,
#  'em': 5,
#  'nossa': 4,
#  'casa': 1,
#  'foi': 2,
#  'hóspede': 1,
#  'ameno': 1,
#  'sorria': 1,
#  'os': 4,
#  'moradores': 1,
#  'com': 7,
#  'ou': 7,
#  'sem': 1,
#  'm': 3,
#  'otivo': 1,
#  'plausível': 1,
#  'era': 1,
#  'sua': 4,
#  'arma': 1,
#  'direi': 1,
#  'secreta': 1,
#  'porque': 4,
#  'ostensiva': 1,
#  'vista': 1,
#  'pessoa': 1,
#  'humana': 1,
#  'lhe': 3,
#  'dá': 1,
#  'prazer': 1,
#  'sorriso': 5,
#  'logo': 1,
#  'considerado': 1,
#  'especial': 1,
#  'revelador': 1,
#  'suas': 3,
#  'intenções': 1,
#  'mundo': 1,
#  'ocidental': 1,
#  'oriental': 1,
#  'particular': 1,
#  'nosso': 1,
#  'trec': 1,
#  'ho': 1,
#  'rua': 1,
#  'fornecedores': 1,
#  'vizinhos': 1,
#  'desconhecidos': 1,
#  'gratificados': 1,
#  'encantador': 1,
#  'apesar': 1,
#  'falta': 2,
#  'dentes': 1,
#  'abonam': 1,
#  'classificação': 1,
#  'devo': 1,
#  'admitir': 1,
#  'que': 13,
#  'como': 4,
#  'visitante': 1,
#  'deu': 1,
#  'trabalho:': 1,
#  'tinha': 2,
#  'horários': 1,
#  'especiais': 5,
#  'comidas': 1,
#  'roupas': 1,
#  'sabonetes': 1,
#  'criados': 1,
#  'mas': 3,
#  'simples': 2,
#  'presença': 1,
#  'compensariam': 1,
#  'providências': 1,
#  'privilégios': 1,
#  'maiores': 1,
#  'recebia': 1,
#  'tudo': 1,
#  'naturalidade': 1,
#  'sabendo-se': 1,
#  'merecedor': 1,
#  'das': 2,
#  'distinções': 1,
#  'ninguém': 1,
#  'lembraria': 1,
#  'achá-lo': 1,
#  'egoísta': 1,
#  'inop': 1,
#  'ortuno': 1,
#  'sono': 1,
#  'apraz': 1,
#  'dormir': 1,
#  'só': 1,
#  'à': 3,
#  'noite': 1,
#  'principalmente': 1,
#  'dia': 1,
#  'eram': 2,
#  'respeitadas': 1,
#  'ritos': 1,
#  'sacros': 1,
#  'ponto': 1,
#  'ousarmos': 1,
#  'erguer': 1,
#  'voz': 1,
#  'acordá-lo': 1,
#  'acordaria': 1,
#  'sorrindo': 1,
#  'costume': 3,
#  'zangaria': 1,
#  'gente': 1,
#  'poré': 1,
#  'perdoaríamos': 1,
#  'corte': 1,
#  'seus': 2,
#  'sonhos': 1,
#  'assim': 1,
#  'por': 2,
#  'conta': 1,
#  'ouvir': 1,
#  'concerto': 1,
#  'violino': 1,
#  'orquestra': 1,
#  'bach': 1,
#  'também': 1,
#  'nossos': 1,
#  'olhos': 2,
#  'ouvidos': 1,
#  'forraram': 1,
#  'tortura': 1,
#  'tv': 1,
#  'andando': 1,
#  'na': 3,
#  'ponta': 1,
#  'dos': 1,
#  'pés': 1,
#  'descalços': 1,
#  'levam': 1,
#  'tropeções': 1,
#  'no': 1,
#  'escuro': 1,
#  'sendo': 1,
#  'amor': 1,
#  'importância': 1,
#  'objeto': 1,
#  'visse': 1,
#  'mão': 1,
#  'requisitava-o': 1,
#  'gosta': 2,
#  'óculos': 1,
#  'alheios': 1,
#  'usa': 1,
#  'relógios': 1,
#  'pulso': 1,
#  'copos': 1,
#  'xícaras': 1,
#  'vidros': 1,
#  'geral': 1,
#  'artigos': 1,
#  'escritório': 2,
#  'botões': 1,
#  'punho': 1,
#  'colecionador;': 1,
#  'coisas': 2,
#  'pegá-las': 1,
#  'mirá-las': 1,
#  'mania': 1,
#  'há': 1,
#  'fazer': 2,
#  'pô-las': 1,
#  'boca': 1,
#  'quem': 1,
#  'conhecer': 1,
#  'dirá': 1,
#  'péssimo': 1,
#  'porém': 1,
#  'duvido': 1,
#  'mantenha': 1,
#  'este': 1,
#  'juízo': 1,
#  'diante': 1,
#  'malícia': 1,
#  'pupilas': 1,
#  'azuis': 2,
#  'me': 4,
#  'esquecia': 1,
#  'tem': 1,
#  'cor': 1,
#  'afasta': 1,
#  'qualquer': 2,
#  'suspeita': 1,
#  'acusação': 1,
#  'apressada': 1,
#  'sobre': 1,
#  'razão': 1,
#  'íntima': 1,
#  'atos': 1,
#  'poderia': 1,
#  'acusá-lo': 1,
#  'incontinência': 1,
#  'sabia': 2,
#  'distinguir': 1,
#  'entre': 1,
#  'cômodos': 1,
#  'ocorria': 1,
#  'fazia': 1,
#  'parte': 1,
#  'zangar-me': 1,
#  'ele': 2,
#  'destruiu': 1,
#  'lâmpada': 1,
#  'do': 1,
#  'jamais': 1,
#  'voltei': 1,
#  'sorrisse;': 1,
#  'tivesse': 1,
#  'eu': 2,
#  'um': 3,
#  'impulso': 1,
#  'irritação': 1,
#  'sentiria': 1,
#  'desarmado': 1,
#  'azul': 1,
#  'maneira': 1,
#  'lhar-me': 1,
#  'essas': 1,
#  'indiferentes': 1,
#  'amizade': 2,
#  'até': 1,
#  'lhes': 1,
#  'conferia': 1,
#  'caráter': 1,
#  'necessário': 1,
#  'prova;': 1,
#  'gratuito': 1,
#  'poesia': 1,
#  'jogo': 1,
#  'fico': 1,
#  'refletindo': 1,
#  'ano': 1,
#  'ida': 1,
#  'companheiro': 1,
#  'já': 1,
#  'vivido': 1,
#  'puído': 1,
#  'repente': 1,
#  'ficou': 1,
#  'vazio': 1}

# %% [markdown]
# ### Vamos responder à pergunta que fizemos:
# >qual a palavra que mais aparece no texto?

# %%
max(repositório, key=repositório.get)
# Out:
# 'de'

# %% [markdown]
# > Quantas vezes a palavra 'de' aparece no texto?

# %%
max(repositório.values())
# Out:
# 34

# %% [markdown]
# ### Conclusão:
# Realizamos tarefas uteis para o estudo da linguagem usando recursos básicos de **Python**. Tudo poderia ser feito de forma mais concisa usando outros recursos (bliotecas, módulos, etc.) baseados em Python. O que, de maneira alguma, dispensa o conhecimento básico: variáveis, tipos de dados, funções, e loops.
